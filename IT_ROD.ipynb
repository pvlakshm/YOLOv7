# %% [markdown]
# <a href="https://colab.research.google.com/github/pvlakshm/YOLOv7/blob/FB1/IT_ROD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
Model
=====
We are using the yolov7 model, and leveraging the implementation from
the "official" yolov7 repo here: https://github.com/WongKinYiu/yolov7. The repo
has the code to do detection, training, generating various metrics with graphs,
and the pre-trained weights.

Stage1
======
We clone the repo, install the dependencies, and just get familiar with
detection right out-of-the-box.
'''
# Out:
# '\nModel\n=====\nWe are using the yolov7 model, and leveraging the implementation from\nthe "official" yolov7 repo here: https://github.com/WongKinYiu/yolov7. The repo\nhas the code to do detection, training, generating various metrics with graphs,\nand the pre-trained weights.\n\nStage1\n======\nWe clone the repo, install the dependencies, and just get familiar with\ndetection right out-of-the-box.\n'

# %%
'''
First, connect to a Runtime tha uses Python and is using a GPU.
Now lets check the GPU we are using.
'''
# !nvidia-smi
# Out:
# Thu Jan  8 09:44:41 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
'''
Clone the repo.
'''
# !git clone https://github.com/WongKinYiu/yolov7.git
# Out:
# Cloning into 'yolov7'...
# remote: Enumerating objects: 1197, done.
# remote: Total 1197 (delta 0), reused 0 (delta 0), pack-reused 1197 (from 1)
# Receiving objects: 100% (1197/1197), 74.29 MiB | 25.88 MiB/s, done.
# Resolving deltas: 100% (511/511), done.

# %%
'''
modernize 2 dependencies in particular
Open requirements.txt and update the entries for numpy and protobuf
as follows:

numpy>=1.26.0
protobuf>=5.29.1
'''
# Out:
# '\nmodernize 2 dependencies in particular\nOpen requirements.txt and update the entries for numpy and protobuf\nas follows:\n\nnumpy>=1.26.0\nprotobuf>=5.29.1\n'

# %%
# !pip install -r /content/yolov7/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 33.3 MB/s eta 0:00:00
# ...

# %%
# %cd yolov7

# %%
# !python detect.py --weights yolov7.pt --conf 0.25 --img-size 640 --source inference/images/horses.jpg
